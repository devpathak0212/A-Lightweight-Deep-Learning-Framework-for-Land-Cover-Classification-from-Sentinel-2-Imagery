# %% [markdown]
# <a href="https://colab.research.google.com/github/devpathak0212/A-Lightweight-Deep-Learning-Framework-for-Land-Cover-Classification-from-Sentinel-2-Imagery/blob/main/Models/Resnet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.1.31)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.3.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.11/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle) (3.10)

# %%
! mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
# !kaggle datasets download pranjallk1995/rgbeurosat
# Out:
# Dataset URL: https://www.kaggle.com/datasets/pranjallk1995/rgbeurosat
# License(s): unknown
# Downloading rgbeurosat.zip to /content
#  97% 87.0M/89.8M [00:03<00:00, 34.5MB/s]
# 100% 89.8M/89.8M [00:03<00:00, 25.5MB/s]

# %%
# !unzip '/content/rgbeurosat.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: RBG/train/SeaLake/SeaLake_1112.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1113.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1115.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1116.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1118.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1119.jpg
#   inflating: RBG/train/SeaLake/SeaLake_112.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1120.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1121.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1122.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1123.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1124.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1126.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1127.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1128.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1129.jpg
#   inflating: RBG/train/SeaLake/SeaLake_113.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1130.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1131.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1132.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1133.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1134.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1136.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1137.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1138.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1139.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1141.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1142.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1144.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1145.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1146.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1147.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1148.jpg
#   inflating: RBG/train/SeaLake/SeaLake_115.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1150.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1151.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1152.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1153.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1155.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1157.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1159.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1160.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1161.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1162.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1163.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1164.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1165.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1166.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1168.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1169.jpg
#   inflating: RBG/train/SeaLake/SeaLake_117.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1170.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1171.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1172.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1173.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1174.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1175.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1176.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1177.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1178.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1179.jpg
#   inflating: RBG/train/SeaLake/SeaLake_118.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1181.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1183.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1185.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1186.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1187.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1188.jpg
#   inflating: RBG/train/SeaLake/SeaLake_119.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1190.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1192.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1193.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1194.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1195.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1198.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1199.jpg
#   inflating: RBG/train/SeaLake/SeaLake_12.jpg
#   inflating: RBG/train/SeaLake/SeaLake_120.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1200.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1203.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1205.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1208.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1209.jpg
#   inflating: RBG/train/SeaLake/SeaLake_121.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1210.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1211.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1212.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1213.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1214.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1217.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1218.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1219.jpg
#   inflating: RBG/train/SeaLake/SeaLake_122.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1220.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1221.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1222.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1223.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1224.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1225.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1227.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1229.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1230.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1231.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1232.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1233.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1234.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1235.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1236.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1237.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1238.jpg
#   inflating: RBG/train/SeaLake/SeaLake_124.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1240.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1241.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1242.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1243.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1245.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1247.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1249.jpg
#   inflating: RBG/train/SeaLake/SeaLake_125.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1251.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1252.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1253.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1254.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1257.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1258.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1259.jpg
#   inflating: RBG/train/SeaLake/SeaLake_126.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1260.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1261.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1262.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1265.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1266.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1267.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1268.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1271.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1272.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1273.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1274.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1275.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1276.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1277.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1278.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1279.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1280.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1281.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1282.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1283.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1284.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1285.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1286.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1289.jpg
#   inflating: RBG/train/SeaLake/SeaLake_129.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1290.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1291.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1292.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1293.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1294.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1296.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1297.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1299.jpg
#   inflating: RBG/train/SeaLake/SeaLake_13.jpg
#   inflating: RBG/train/SeaLake/SeaLake_130.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1300.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1302.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1303.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1304.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1305.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1306.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1307.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1308.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1309.jpg
#   inflating: RBG/train/SeaLake/SeaLake_131.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1310.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1311.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1312.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1313.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1315.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1316.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1317.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1318.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1319.jpg
#   inflating: RBG/train/SeaLake/SeaLake_132.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1320.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1321.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1323.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1324.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1325.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1329.jpg
#   inflating: RBG/train/SeaLake/SeaLake_133.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1330.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1331.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1333.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1334.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1335.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1336.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1337.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1338.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1339.jpg
#   inflating: RBG/train/SeaLake/SeaLake_134.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1340.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1342.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1343.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1344.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1345.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1346.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1347.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1348.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1349.jpg
#   inflating: RBG/train/SeaLake/SeaLake_135.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1350.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1351.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1352.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1353.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1354.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1355.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1356.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1357.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1358.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1359.jpg
#   inflating: RBG/train/SeaLake/SeaLake_136.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1360.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1361.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1362.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1363.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1364.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1365.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1366.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1367.jpg
#   inflating: RBG/train/SeaLake/SeaLake_137.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1370.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1371.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1372.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1373.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1374.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1375.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1377.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1379.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1380.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1381.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1382.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1385.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1386.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1387.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1388.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1389.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1390.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1392.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1393.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1394.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1395.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1397.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1398.jpg
#   inflating: RBG/train/SeaLake/SeaLake_14.jpg
#   inflating: RBG/train/SeaLake/SeaLake_140.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1401.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1402.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1403.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1404.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1406.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1407.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1408.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1409.jpg
#   inflating: RBG/train/SeaLake/SeaLake_141.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1410.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1411.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1412.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1413.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1414.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1415.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1416.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1418.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1419.jpg
#   inflating: RBG/train/SeaLake/SeaLake_142.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1420.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1421.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1423.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1424.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1425.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1426.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1427.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1428.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1429.jpg
#   inflating: RBG/train/SeaLake/SeaLake_143.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1430.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1431.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1432.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1433.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1434.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1436.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1437.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1438.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1439.jpg
#   inflating: RBG/train/SeaLake/SeaLake_144.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1440.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1441.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1442.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1443.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1444.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1445.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1447.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1448.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1449.jpg
#   inflating: RBG/train/SeaLake/SeaLake_145.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1450.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1451.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1452.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1453.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1455.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1456.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1457.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1458.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1459.jpg
#   inflating: RBG/train/SeaLake/SeaLake_146.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1460.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1461.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1462.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1463.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1464.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1465.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1466.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1467.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1468.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1469.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1470.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1471.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1472.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1473.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1476.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1477.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1478.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1479.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1481.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1482.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1483.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1484.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1485.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1486.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1487.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1488.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1489.jpg
#   inflating: RBG/train/SeaLake/SeaLake_149.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1490.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1491.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1492.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1493.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1494.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1495.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1496.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1497.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1498.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1499.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1500.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1501.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1502.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1503.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1504.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1505.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1506.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1507.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1508.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1509.jpg
#   inflating: RBG/train/SeaLake/SeaLake_151.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1510.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1511.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1514.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1515.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1516.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1517.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1518.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1519.jpg
#   inflating: RBG/train/SeaLake/SeaLake_152.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1520.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1521.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1522.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1523.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1524.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1525.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1526.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1527.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1528.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1529.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1530.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1532.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1534.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1535.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1536.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1538.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1539.jpg
#   inflating: RBG/train/SeaLake/SeaLake_154.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1540.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1541.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1542.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1543.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1545.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1546.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1548.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1549.jpg
#   inflating: RBG/train/SeaLake/SeaLake_155.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1550.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1552.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1553.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1554.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1555.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1557.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1558.jpg
#   inflating: RBG/train/SeaLake/SeaLake_156.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1562.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1564.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1565.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1566.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1568.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1569.jpg
#   inflating: RBG/train/SeaLake/SeaLake_157.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1570.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1571.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1574.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1575.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1576.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1578.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1579.jpg
#   inflating: RBG/train/SeaLake/SeaLake_158.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1580.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1582.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1583.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1584.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1586.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1589.jpg
#   inflating: RBG/train/SeaLake/SeaLake_159.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1590.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1591.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1592.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1593.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1594.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1595.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1596.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1598.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1599.jpg
#   inflating: RBG/train/SeaLake/SeaLake_16.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1602.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1603.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1604.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1605.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1606.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1607.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1608.jpg
#   inflating: RBG/train/SeaLake/SeaLake_161.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1610.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1611.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1612.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1613.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1614.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1615.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1616.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1617.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1618.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1619.jpg
#   inflating: RBG/train/SeaLake/SeaLake_162.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1620.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1621.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1623.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1626.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1627.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1628.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1629.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1630.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1631.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1632.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1633.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1634.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1635.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1636.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1637.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1638.jpg
#   inflating: RBG/train/SeaLake/SeaLake_164.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1640.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1641.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1642.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1643.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1645.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1646.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1647.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1648.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1649.jpg
#   inflating: RBG/train/SeaLake/SeaLake_165.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1651.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1652.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1653.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1654.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1655.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1656.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1658.jpg
#   inflating: RBG/train/SeaLake/SeaLake_166.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1660.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1661.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1662.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1663.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1664.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1666.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1667.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1668.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1669.jpg
#   inflating: RBG/train/SeaLake/SeaLake_167.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1670.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1671.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1672.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1673.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1674.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1677.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1678.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1679.jpg
#   inflating: RBG/train/SeaLake/SeaLake_168.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1681.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1682.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1684.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1686.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1687.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1688.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1689.jpg
#   inflating: RBG/train/SeaLake/SeaLake_169.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1690.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1691.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1692.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1693.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1694.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1695.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1697.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1699.jpg
#   inflating: RBG/train/SeaLake/SeaLake_17.jpg
#   inflating: RBG/train/SeaLake/SeaLake_170.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1700.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1701.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1702.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1703.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1707.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1708.jpg
#   inflating: RBG/train/SeaLake/SeaLake_171.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1710.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1711.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1713.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1716.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1717.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1718.jpg
#   inflating: RBG/train/SeaLake/SeaLake_172.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1720.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1721.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1722.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1726.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1727.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1728.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1729.jpg
#   inflating: RBG/train/SeaLake/SeaLake_173.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1730.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1731.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1732.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1735.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1736.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1737.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1738.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1739.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1741.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1742.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1743.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1744.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1745.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1746.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1747.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1748.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1749.jpg
#   inflating: RBG/train/SeaLake/SeaLake_175.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1750.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1751.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1752.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1755.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1756.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1757.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1758.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1759.jpg
#   inflating: RBG/train/SeaLake/SeaLake_176.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1760.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1761.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1762.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1763.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1765.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1766.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1768.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1769.jpg
#   inflating: RBG/train/SeaLake/SeaLake_177.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1770.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1771.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1772.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1773.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1774.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1775.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1776.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1777.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1778.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1779.jpg
#   inflating: RBG/train/SeaLake/SeaLake_178.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1780.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1781.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1783.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1784.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1786.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1788.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1789.jpg
#   inflating: RBG/train/SeaLake/SeaLake_179.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1790.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1791.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1792.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1793.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1794.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1797.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1799.jpg
#   inflating: RBG/train/SeaLake/SeaLake_18.jpg
#   inflating: RBG/train/SeaLake/SeaLake_180.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1800.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1801.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1802.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1803.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1804.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1805.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1806.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1807.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1808.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1809.jpg
#   inflating: RBG/train/SeaLake/SeaLake_181.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1810.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1811.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1812.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1813.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1814.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1816.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1818.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1820.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1821.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1823.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1824.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1825.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1826.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1827.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1829.jpg
#   inflating: RBG/train/SeaLake/SeaLake_183.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1830.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1831.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1832.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1833.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1834.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1835.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1836.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1838.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1839.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1840.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1841.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1843.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1845.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1846.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1847.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1848.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1849.jpg
#   inflating: RBG/train/SeaLake/SeaLake_185.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1850.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1851.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1853.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1854.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1856.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1857.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1858.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1859.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1860.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1861.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1862.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1864.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1865.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1866.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1867.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1868.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1869.jpg
#   inflating: RBG/train/SeaLake/SeaLake_187.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1870.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1874.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1875.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1876.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1877.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1878.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1879.jpg
#   inflating: RBG/train/SeaLake/SeaLake_188.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1880.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1881.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1882.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1883.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1884.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1885.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1886.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1887.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1888.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1889.jpg
#   inflating: RBG/train/SeaLake/SeaLake_189.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1890.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1891.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1893.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1894.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1896.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1897.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1898.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1899.jpg
#   inflating: RBG/train/SeaLake/SeaLake_19.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1900.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1901.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1902.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1904.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1905.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1906.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1908.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1909.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1910.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1911.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1912.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1913.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1914.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1915.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1916.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1917.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1918.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1919.jpg
#   inflating: RBG/train/SeaLake/SeaLake_192.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1920.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1922.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1923.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1924.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1925.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1927.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1928.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1929.jpg
#   inflating: RBG/train/SeaLake/SeaLake_193.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1932.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1933.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1934.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1935.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1936.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1938.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1939.jpg
#   inflating: RBG/train/SeaLake/SeaLake_194.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1940.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1941.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1943.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1944.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1946.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1948.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1949.jpg
#   inflating: RBG/train/SeaLake/SeaLake_195.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1950.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1951.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1952.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1953.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1954.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1955.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1956.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1957.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1958.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1959.jpg
#   inflating: RBG/train/SeaLake/SeaLake_196.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1960.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1961.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1962.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1965.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1967.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1968.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1969.jpg
#   inflating: RBG/train/SeaLake/SeaLake_197.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1971.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1972.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1973.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1974.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1976.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1978.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1979.jpg
#   inflating: RBG/train/SeaLake/SeaLake_198.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1980.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1981.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1983.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1984.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1985.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1986.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1987.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1988.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1989.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1991.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1992.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1993.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1994.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1995.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1996.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1998.jpg
#   inflating: RBG/train/SeaLake/SeaLake_1999.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2.jpg
#   inflating: RBG/train/SeaLake/SeaLake_20.jpg
#   inflating: RBG/train/SeaLake/SeaLake_200.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2000.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2001.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2002.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2003.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2005.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2006.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2007.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2008.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2009.jpg
#   inflating: RBG/train/SeaLake/SeaLake_201.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2010.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2011.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2014.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2015.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2016.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2017.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2019.jpg
#   inflating: RBG/train/SeaLake/SeaLake_202.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2020.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2021.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2022.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2023.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2025.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2026.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2027.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2028.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2029.jpg
#   inflating: RBG/train/SeaLake/SeaLake_203.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2030.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2031.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2032.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2034.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2035.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2037.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2038.jpg
#   inflating: RBG/train/SeaLake/SeaLake_204.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2040.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2041.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2042.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2043.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2044.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2045.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2046.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2047.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2048.jpg
#   inflating: RBG/train/SeaLake/SeaLake_205.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2050.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2052.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2054.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2055.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2057.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2059.jpg
#   inflating: RBG/train/SeaLake/SeaLake_206.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2060.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2061.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2062.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2063.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2064.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2065.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2066.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2067.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2068.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2069.jpg
#   inflating: RBG/train/SeaLake/SeaLake_207.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2071.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2072.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2073.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2074.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2075.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2076.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2077.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2078.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2079.jpg
#   inflating: RBG/train/SeaLake/SeaLake_208.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2080.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2081.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2082.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2083.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2084.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2085.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2086.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2087.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2088.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2089.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2091.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2092.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2093.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2094.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2096.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2097.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2098.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2099.jpg
#   inflating: RBG/train/SeaLake/SeaLake_21.jpg
#   inflating: RBG/train/SeaLake/SeaLake_210.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2102.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2103.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2104.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2105.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2106.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2107.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2108.jpg
#   inflating: RBG/train/SeaLake/SeaLake_211.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2110.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2111.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2112.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2113.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2115.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2116.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2118.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2119.jpg
#   inflating: RBG/train/SeaLake/SeaLake_212.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2120.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2121.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2122.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2125.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2126.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2127.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2128.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2129.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2131.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2134.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2135.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2136.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2137.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2138.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2139.jpg
#   inflating: RBG/train/SeaLake/SeaLake_214.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2141.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2143.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2145.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2146.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2147.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2148.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2149.jpg
#   inflating: RBG/train/SeaLake/SeaLake_215.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2150.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2152.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2153.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2156.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2158.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2159.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2160.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2161.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2162.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2164.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2165.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2166.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2168.jpg
#   inflating: RBG/train/SeaLake/SeaLake_217.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2170.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2171.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2172.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2173.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2174.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2175.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2176.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2177.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2178.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2179.jpg
#   inflating: RBG/train/SeaLake/SeaLake_218.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2181.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2182.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2185.jpg
#   inflating: RBG/train/SeaLake/SeaLake_2186.jpg
# ...
#   inflating: RBG/val/River/River_676.jpg
#   inflating: RBG/val/River/River_677.jpg
#   inflating: RBG/val/River/River_679.jpg
#   inflating: RBG/val/River/River_684.jpg
#   inflating: RBG/val/River/River_685.jpg
#   inflating: RBG/val/River/River_698.jpg
#   inflating: RBG/val/River/River_710.jpg
#   inflating: RBG/val/River/River_713.jpg
#   inflating: RBG/val/River/River_731.jpg
#   inflating: RBG/val/River/River_733.jpg
#   inflating: RBG/val/River/River_74.jpg
#   inflating: RBG/val/River/River_743.jpg
#   inflating: RBG/val/River/River_745.jpg
#   inflating: RBG/val/River/River_750.jpg
#   inflating: RBG/val/River/River_753.jpg
#   inflating: RBG/val/River/River_766.jpg
#   inflating: RBG/val/River/River_790.jpg
#   inflating: RBG/val/River/River_798.jpg
#   inflating: RBG/val/River/River_800.jpg
#   inflating: RBG/val/River/River_818.jpg
#   inflating: RBG/val/River/River_823.jpg
#   inflating: RBG/val/River/River_824.jpg
#   inflating: RBG/val/River/River_84.jpg
#   inflating: RBG/val/River/River_847.jpg
#   inflating: RBG/val/River/River_862.jpg
#   inflating: RBG/val/River/River_869.jpg
#   inflating: RBG/val/River/River_875.jpg
#   inflating: RBG/val/River/River_879.jpg
#   inflating: RBG/val/River/River_899.jpg
#   inflating: RBG/val/River/River_941.jpg
#   inflating: RBG/val/River/River_948.jpg
#   inflating: RBG/val/River/River_949.jpg
#   inflating: RBG/val/River/River_958.jpg
#   inflating: RBG/val/River/River_966.jpg
#   inflating: RBG/val/River/River_97.jpg
#   inflating: RBG/val/River/River_982.jpg
#   inflating: RBG/val/River/River_983.jpg
#   inflating: RBG/val/River/River_990.jpg
#   inflating: RBG/val/River/River_993.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1003.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1006.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1013.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1023.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1042.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1045.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1047.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1062.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1073.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1076.jpg
#   inflating: RBG/val/SeaLake/SeaLake_109.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1097.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1099.jpg
#   inflating: RBG/val/SeaLake/SeaLake_11.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1110.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1114.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1117.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1125.jpg
#   inflating: RBG/val/SeaLake/SeaLake_114.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1140.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1149.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1180.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1182.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1189.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1201.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1202.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1206.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1207.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1226.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1228.jpg
#   inflating: RBG/val/SeaLake/SeaLake_123.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1255.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1256.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1263.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1269.jpg
#   inflating: RBG/val/SeaLake/SeaLake_127.jpg
#   inflating: RBG/val/SeaLake/SeaLake_128.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1301.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1322.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1326.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1327.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1328.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1332.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1341.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1368.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1369.jpg
#   inflating: RBG/val/SeaLake/SeaLake_138.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1383.jpg
#   inflating: RBG/val/SeaLake/SeaLake_139.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1396.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1399.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1405.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1446.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1454.jpg
#   inflating: RBG/val/SeaLake/SeaLake_147.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1474.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1475.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1480.jpg
#   inflating: RBG/val/SeaLake/SeaLake_15.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1513.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1531.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1533.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1537.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1556.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1559.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1561.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1563.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1567.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1573.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1581.jpg
#   inflating: RBG/val/SeaLake/SeaLake_160.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1600.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1601.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1622.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1639.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1650.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1657.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1659.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1675.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1676.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1683.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1685.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1696.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1698.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1733.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1734.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1740.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1753.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1764.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1785.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1795.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1796.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1798.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1817.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1819.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1822.jpg
#   inflating: RBG/val/SeaLake/SeaLake_184.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1844.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1852.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1855.jpg
#   inflating: RBG/val/SeaLake/SeaLake_186.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1863.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1873.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1892.jpg
#   inflating: RBG/val/SeaLake/SeaLake_191.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1921.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1926.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1937.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1942.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1945.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1963.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1966.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1977.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1982.jpg
#   inflating: RBG/val/SeaLake/SeaLake_199.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1990.jpg
#   inflating: RBG/val/SeaLake/SeaLake_1997.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2033.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2036.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2039.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2051.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2053.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2056.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2070.jpg
#   inflating: RBG/val/SeaLake/SeaLake_209.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2095.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2101.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2114.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2117.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2124.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2133.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2140.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2142.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2154.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2167.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2169.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2180.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2183.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2187.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2188.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2193.jpg
#   inflating: RBG/val/SeaLake/SeaLake_22.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2217.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2246.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2247.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2252.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2253.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2264.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2265.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2278.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2289.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2295.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2327.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2328.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2337.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2350.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2368.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2369.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2375.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2378.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2383.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2418.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2422.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2426.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2429.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2449.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2454.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2457.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2462.jpg
#   inflating: RBG/val/SeaLake/SeaLake_247.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2470.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2481.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2483.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2501.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2505.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2520.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2526.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2539.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2549.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2553.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2555.jpg
#   inflating: RBG/val/SeaLake/SeaLake_256.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2566.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2577.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2599.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2606.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2609.jpg
#   inflating: RBG/val/SeaLake/SeaLake_261.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2614.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2647.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2650.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2662.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2669.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2679.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2681.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2687.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2692.jpg
#   inflating: RBG/val/SeaLake/SeaLake_274.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2743.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2759.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2784.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2791.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2803.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2807.jpg
#   inflating: RBG/val/SeaLake/SeaLake_283.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2830.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2837.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2847.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2883.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2885.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2892.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2899.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2906.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2907.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2926.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2927.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2929.jpg
#   inflating: RBG/val/SeaLake/SeaLake_293.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2934.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2948.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2954.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2962.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2973.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2975.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2984.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2993.jpg
#   inflating: RBG/val/SeaLake/SeaLake_2994.jpg
#   inflating: RBG/val/SeaLake/SeaLake_313.jpg
#   inflating: RBG/val/SeaLake/SeaLake_328.jpg
#   inflating: RBG/val/SeaLake/SeaLake_33.jpg
#   inflating: RBG/val/SeaLake/SeaLake_348.jpg
#   inflating: RBG/val/SeaLake/SeaLake_368.jpg
#   inflating: RBG/val/SeaLake/SeaLake_370.jpg
#   inflating: RBG/val/SeaLake/SeaLake_372.jpg
#   inflating: RBG/val/SeaLake/SeaLake_389.jpg
#   inflating: RBG/val/SeaLake/SeaLake_391.jpg
#   inflating: RBG/val/SeaLake/SeaLake_393.jpg
#   inflating: RBG/val/SeaLake/SeaLake_401.jpg
#   inflating: RBG/val/SeaLake/SeaLake_408.jpg
#   inflating: RBG/val/SeaLake/SeaLake_438.jpg
#   inflating: RBG/val/SeaLake/SeaLake_452.jpg
#   inflating: RBG/val/SeaLake/SeaLake_453.jpg
#   inflating: RBG/val/SeaLake/SeaLake_455.jpg
#   inflating: RBG/val/SeaLake/SeaLake_467.jpg
#   inflating: RBG/val/SeaLake/SeaLake_47.jpg
#   inflating: RBG/val/SeaLake/SeaLake_479.jpg
#   inflating: RBG/val/SeaLake/SeaLake_480.jpg
#   inflating: RBG/val/SeaLake/SeaLake_5.jpg
#   inflating: RBG/val/SeaLake/SeaLake_506.jpg
#   inflating: RBG/val/SeaLake/SeaLake_515.jpg
#   inflating: RBG/val/SeaLake/SeaLake_520.jpg
#   inflating: RBG/val/SeaLake/SeaLake_551.jpg
#   inflating: RBG/val/SeaLake/SeaLake_558.jpg
#   inflating: RBG/val/SeaLake/SeaLake_560.jpg
#   inflating: RBG/val/SeaLake/SeaLake_564.jpg
#   inflating: RBG/val/SeaLake/SeaLake_566.jpg
#   inflating: RBG/val/SeaLake/SeaLake_578.jpg
#   inflating: RBG/val/SeaLake/SeaLake_582.jpg
#   inflating: RBG/val/SeaLake/SeaLake_587.jpg
#   inflating: RBG/val/SeaLake/SeaLake_59.jpg
#   inflating: RBG/val/SeaLake/SeaLake_596.jpg
#   inflating: RBG/val/SeaLake/SeaLake_597.jpg
#   inflating: RBG/val/SeaLake/SeaLake_605.jpg
#   inflating: RBG/val/SeaLake/SeaLake_607.jpg
#   inflating: RBG/val/SeaLake/SeaLake_631.jpg
#   inflating: RBG/val/SeaLake/SeaLake_637.jpg
#   inflating: RBG/val/SeaLake/SeaLake_657.jpg
#   inflating: RBG/val/SeaLake/SeaLake_663.jpg
#   inflating: RBG/val/SeaLake/SeaLake_684.jpg
#   inflating: RBG/val/SeaLake/SeaLake_703.jpg
#   inflating: RBG/val/SeaLake/SeaLake_729.jpg
#   inflating: RBG/val/SeaLake/SeaLake_730.jpg
#   inflating: RBG/val/SeaLake/SeaLake_737.jpg
#   inflating: RBG/val/SeaLake/SeaLake_739.jpg
#   inflating: RBG/val/SeaLake/SeaLake_772.jpg
#   inflating: RBG/val/SeaLake/SeaLake_793.jpg
#   inflating: RBG/val/SeaLake/SeaLake_800.jpg
#   inflating: RBG/val/SeaLake/SeaLake_804.jpg
#   inflating: RBG/val/SeaLake/SeaLake_823.jpg
#   inflating: RBG/val/SeaLake/SeaLake_827.jpg
#   inflating: RBG/val/SeaLake/SeaLake_830.jpg
#   inflating: RBG/val/SeaLake/SeaLake_837.jpg
#   inflating: RBG/val/SeaLake/SeaLake_843.jpg
#   inflating: RBG/val/SeaLake/SeaLake_851.jpg
#   inflating: RBG/val/SeaLake/SeaLake_853.jpg
#   inflating: RBG/val/SeaLake/SeaLake_879.jpg
#   inflating: RBG/val/SeaLake/SeaLake_897.jpg
#   inflating: RBG/val/SeaLake/SeaLake_908.jpg
#   inflating: RBG/val/SeaLake/SeaLake_921.jpg
#   inflating: RBG/val/SeaLake/SeaLake_930.jpg
#   inflating: RBG/val/SeaLake/SeaLake_933.jpg
#   inflating: RBG/val/SeaLake/SeaLake_945.jpg
#   inflating: RBG/val/SeaLake/SeaLake_95.jpg
#   inflating: RBG/val/SeaLake/SeaLake_952.jpg
#   inflating: RBG/val/SeaLake/SeaLake_972.jpg
#   inflating: RBG/val/SeaLake/SeaLake_975.jpg
#   inflating: RBG/val/SeaLake/SeaLake_976.jpg
#   inflating: RBG/val/SeaLake/SeaLake_985.jpg
#   inflating: RBG/val/SeaLake/SeaLake_988.jpg
#   inflating: RBG/val/SeaLake/SeaLake_991.jpg

# %%
# Essential and common packages
import os
import glob
import time

# Read and visualize the raster data
# import rasterio
# from rasterio.plot import show

# Plots and bars
import matplotlib.pyplot as plt
import seaborn as sns

# Computation library
import numpy as np

from tensorflow.keras.models import Sequential

# Tensorflow for building the resnet50 model
import tensorflow.python.keras as k
import tensorflow as tf
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.initializers import RandomUniform, GlorotUniform

from tensorflow.keras.optimizers import Adam

#Tensorflow for DenseNet121 model
from tensorflow.keras.applications import DenseNet121

#Tensorflow for EficientNetB2 model
from tensorflow.keras.applications import EfficientNetB2

#Tensorflow for ResNet50 model
from tensorflow.keras.applications import ResNet50

from tensorflow.keras.models import Model

# Sklearn for confusion matrix and classification report
import itertools
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report

# For visualization of plots without plt.show()
# %matplotlib inline

# %%
dataset_url = r'/content/RBG/train'
batch_size = 32
img_height = 64
img_width = 64
validation_split=0.2
rescale=1.0/255

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(validation_split=validation_split, rescale=rescale)
dataset = tf.keras.preprocessing.image_dataset_from_directory(dataset_url, image_size=(img_height, img_width), batch_size=batch_size)
# Out:
# Found 21600 files belonging to 10 classes.

# %%
train_dataset = datagen.flow_from_directory(batch_size=batch_size,
                                           directory=dataset_url,
                                           shuffle=True,
                                           target_size=(img_height, img_width),
                                           subset="training",
                                           class_mode='categorical')
# Out:
# Found 17280 images belonging to 10 classes.

# %%
test_dataset = datagen.flow_from_directory(batch_size=batch_size,
                                           directory=dataset_url,
                                           shuffle=True,
                                           target_size=(img_height, img_width),
                                           subset="validation",
                                           class_mode='categorical')
# Out:
# Found 4320 images belonging to 10 classes.

# %%
class_names = dataset.class_names
plt.figure(figsize=(10, 10))
for images, labels in dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
model= ResNet50(include_top=False,
                   input_shape=(64,64,3),
                   pooling='avg',classes=10,
                   weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
for layer in model.layers:
        layer.trainable=False

# %%
model.layers
# Out:
# [<InputLayer name=input_layer, built=True>,
#  <ZeroPadding2D name=conv1_pad, built=True>,
#  <Conv2D name=conv1_conv, built=True>,
#  <BatchNormalization name=conv1_bn, built=True>,
#  <Activation name=conv1_relu, built=True>,
#  <ZeroPadding2D name=pool1_pad, built=True>,
#  <MaxPooling2D name=pool1_pool, built=True>,
#  <Conv2D name=conv2_block1_1_conv, built=True>,
#  <BatchNormalization name=conv2_block1_1_bn, built=True>,
#  <Activation name=conv2_block1_1_relu, built=True>,
#  <Conv2D name=conv2_block1_2_conv, built=True>,
#  <BatchNormalization name=conv2_block1_2_bn, built=True>,
#  <Activation name=conv2_block1_2_relu, built=True>,
#  <Conv2D name=conv2_block1_0_conv, built=True>,
#  <Conv2D name=conv2_block1_3_conv, built=True>,
#  <BatchNormalization name=conv2_block1_0_bn, built=True>,
#  <BatchNormalization name=conv2_block1_3_bn, built=True>,
#  <Add name=conv2_block1_add, built=True>,
#  <Activation name=conv2_block1_out, built=True>,
#  <Conv2D name=conv2_block2_1_conv, built=True>,
#  <BatchNormalization name=conv2_block2_1_bn, built=True>,
#  <Activation name=conv2_block2_1_relu, built=True>,
#  <Conv2D name=conv2_block2_2_conv, built=True>,
#  <BatchNormalization name=conv2_block2_2_bn, built=True>,
#  <Activation name=conv2_block2_2_relu, built=True>,
#  <Conv2D name=conv2_block2_3_conv, built=True>,
#  <BatchNormalization name=conv2_block2_3_bn, built=True>,
#  <Add name=conv2_block2_add, built=True>,
#  <Activation name=conv2_block2_out, built=True>,
#  <Conv2D name=conv2_block3_1_conv, built=True>,
#  <BatchNormalization name=conv2_block3_1_bn, built=True>,
#  <Activation name=conv2_block3_1_relu, built=True>,
#  <Conv2D name=conv2_block3_2_conv, built=True>,
#  <BatchNormalization name=conv2_block3_2_bn, built=True>,
#  <Activation name=conv2_block3_2_relu, built=True>,
#  <Conv2D name=conv2_block3_3_conv, built=True>,
#  <BatchNormalization name=conv2_block3_3_bn, built=True>,
#  <Add name=conv2_block3_add, built=True>,
#  <Activation name=conv2_block3_out, built=True>,
#  <Conv2D name=conv3_block1_1_conv, built=True>,
#  <BatchNormalization name=conv3_block1_1_bn, built=True>,
#  <Activation name=conv3_block1_1_relu, built=True>,
#  <Conv2D name=conv3_block1_2_conv, built=True>,
#  <BatchNormalization name=conv3_block1_2_bn, built=True>,
#  <Activation name=conv3_block1_2_relu, built=True>,
#  <Conv2D name=conv3_block1_0_conv, built=True>,
#  <Conv2D name=conv3_block1_3_conv, built=True>,
#  <BatchNormalization name=conv3_block1_0_bn, built=True>,
#  <BatchNormalization name=conv3_block1_3_bn, built=True>,
#  <Add name=conv3_block1_add, built=True>,
#  <Activation name=conv3_block1_out, built=True>,
#  <Conv2D name=conv3_block2_1_conv, built=True>,
#  <BatchNormalization name=conv3_block2_1_bn, built=True>,
#  <Activation name=conv3_block2_1_relu, built=True>,
#  <Conv2D name=conv3_block2_2_conv, built=True>,
#  <BatchNormalization name=conv3_block2_2_bn, built=True>,
#  <Activation name=conv3_block2_2_relu, built=True>,
#  <Conv2D name=conv3_block2_3_conv, built=True>,
#  <BatchNormalization name=conv3_block2_3_bn, built=True>,
#  <Add name=conv3_block2_add, built=True>,
#  <Activation name=conv3_block2_out, built=True>,
#  <Conv2D name=conv3_block3_1_conv, built=True>,
#  <BatchNormalization name=conv3_block3_1_bn, built=True>,
#  <Activation name=conv3_block3_1_relu, built=True>,
#  <Conv2D name=conv3_block3_2_conv, built=True>,
#  <BatchNormalization name=conv3_block3_2_bn, built=True>,
#  <Activation name=conv3_block3_2_relu, built=True>,
#  <Conv2D name=conv3_block3_3_conv, built=True>,
#  <BatchNormalization name=conv3_block3_3_bn, built=True>,
#  <Add name=conv3_block3_add, built=True>,
#  <Activation name=conv3_block3_out, built=True>,
#  <Conv2D name=conv3_block4_1_conv, built=True>,
#  <BatchNormalization name=conv3_block4_1_bn, built=True>,
#  <Activation name=conv3_block4_1_relu, built=True>,
#  <Conv2D name=conv3_block4_2_conv, built=True>,
#  <BatchNormalization name=conv3_block4_2_bn, built=True>,
#  <Activation name=conv3_block4_2_relu, built=True>,
#  <Conv2D name=conv3_block4_3_conv, built=True>,
#  <BatchNormalization name=conv3_block4_3_bn, built=True>,
#  <Add name=conv3_block4_add, built=True>,
#  <Activation name=conv3_block4_out, built=True>,
#  <Conv2D name=conv4_block1_1_conv, built=True>,
#  <BatchNormalization name=conv4_block1_1_bn, built=True>,
#  <Activation name=conv4_block1_1_relu, built=True>,
#  <Conv2D name=conv4_block1_2_conv, built=True>,
#  <BatchNormalization name=conv4_block1_2_bn, built=True>,
#  <Activation name=conv4_block1_2_relu, built=True>,
#  <Conv2D name=conv4_block1_0_conv, built=True>,
#  <Conv2D name=conv4_block1_3_conv, built=True>,
#  <BatchNormalization name=conv4_block1_0_bn, built=True>,
#  <BatchNormalization name=conv4_block1_3_bn, built=True>,
#  <Add name=conv4_block1_add, built=True>,
#  <Activation name=conv4_block1_out, built=True>,
#  <Conv2D name=conv4_block2_1_conv, built=True>,
#  <BatchNormalization name=conv4_block2_1_bn, built=True>,
#  <Activation name=conv4_block2_1_relu, built=True>,
#  <Conv2D name=conv4_block2_2_conv, built=True>,
#  <BatchNormalization name=conv4_block2_2_bn, built=True>,
#  <Activation name=conv4_block2_2_relu, built=True>,
#  <Conv2D name=conv4_block2_3_conv, built=True>,
#  <BatchNormalization name=conv4_block2_3_bn, built=True>,
#  <Add name=conv4_block2_add, built=True>,
#  <Activation name=conv4_block2_out, built=True>,
#  <Conv2D name=conv4_block3_1_conv, built=True>,
#  <BatchNormalization name=conv4_block3_1_bn, built=True>,
#  <Activation name=conv4_block3_1_relu, built=True>,
#  <Conv2D name=conv4_block3_2_conv, built=True>,
#  <BatchNormalization name=conv4_block3_2_bn, built=True>,
#  <Activation name=conv4_block3_2_relu, built=True>,
#  <Conv2D name=conv4_block3_3_conv, built=True>,
#  <BatchNormalization name=conv4_block3_3_bn, built=True>,
#  <Add name=conv4_block3_add, built=True>,
#  <Activation name=conv4_block3_out, built=True>,
#  <Conv2D name=conv4_block4_1_conv, built=True>,
#  <BatchNormalization name=conv4_block4_1_bn, built=True>,
#  <Activation name=conv4_block4_1_relu, built=True>,
#  <Conv2D name=conv4_block4_2_conv, built=True>,
#  <BatchNormalization name=conv4_block4_2_bn, built=True>,
#  <Activation name=conv4_block4_2_relu, built=True>,
#  <Conv2D name=conv4_block4_3_conv, built=True>,
#  <BatchNormalization name=conv4_block4_3_bn, built=True>,
#  <Add name=conv4_block4_add, built=True>,
#  <Activation name=conv4_block4_out, built=True>,
#  <Conv2D name=conv4_block5_1_conv, built=True>,
#  <BatchNormalization name=conv4_block5_1_bn, built=True>,
#  <Activation name=conv4_block5_1_relu, built=True>,
#  <Conv2D name=conv4_block5_2_conv, built=True>,
#  <BatchNormalization name=conv4_block5_2_bn, built=True>,
#  <Activation name=conv4_block5_2_relu, built=True>,
#  <Conv2D name=conv4_block5_3_conv, built=True>,
#  <BatchNormalization name=conv4_block5_3_bn, built=True>,
#  <Add name=conv4_block5_add, built=True>,
#  <Activation name=conv4_block5_out, built=True>,
#  <Conv2D name=conv4_block6_1_conv, built=True>,
#  <BatchNormalization name=conv4_block6_1_bn, built=True>,
#  <Activation name=conv4_block6_1_relu, built=True>,
#  <Conv2D name=conv4_block6_2_conv, built=True>,
#  <BatchNormalization name=conv4_block6_2_bn, built=True>,
#  <Activation name=conv4_block6_2_relu, built=True>,
#  <Conv2D name=conv4_block6_3_conv, built=True>,
#  <BatchNormalization name=conv4_block6_3_bn, built=True>,
#  <Add name=conv4_block6_add, built=True>,
#  <Activation name=conv4_block6_out, built=True>,
#  <Conv2D name=conv5_block1_1_conv, built=True>,
#  <BatchNormalization name=conv5_block1_1_bn, built=True>,
#  <Activation name=conv5_block1_1_relu, built=True>,
#  <Conv2D name=conv5_block1_2_conv, built=True>,
#  <BatchNormalization name=conv5_block1_2_bn, built=True>,
#  <Activation name=conv5_block1_2_relu, built=True>,
#  <Conv2D name=conv5_block1_0_conv, built=True>,
#  <Conv2D name=conv5_block1_3_conv, built=True>,
#  <BatchNormalization name=conv5_block1_0_bn, built=True>,
#  <BatchNormalization name=conv5_block1_3_bn, built=True>,
#  <Add name=conv5_block1_add, built=True>,
#  <Activation name=conv5_block1_out, built=True>,
#  <Conv2D name=conv5_block2_1_conv, built=True>,
#  <BatchNormalization name=conv5_block2_1_bn, built=True>,
#  <Activation name=conv5_block2_1_relu, built=True>,
#  <Conv2D name=conv5_block2_2_conv, built=True>,
#  <BatchNormalization name=conv5_block2_2_bn, built=True>,
#  <Activation name=conv5_block2_2_relu, built=True>,
#  <Conv2D name=conv5_block2_3_conv, built=True>,
#  <BatchNormalization name=conv5_block2_3_bn, built=True>,
#  <Add name=conv5_block2_add, built=True>,
#  <Activation name=conv5_block2_out, built=True>,
#  <Conv2D name=conv5_block3_1_conv, built=True>,
#  <BatchNormalization name=conv5_block3_1_bn, built=True>,
#  <Activation name=conv5_block3_1_relu, built=True>,
#  <Conv2D name=conv5_block3_2_conv, built=True>,
#  <BatchNormalization name=conv5_block3_2_bn, built=True>,
#  <Activation name=conv5_block3_2_relu, built=True>,
#  <Conv2D name=conv5_block3_3_conv, built=True>,
#  <BatchNormalization name=conv5_block3_3_bn, built=True>,
#  <Add name=conv5_block3_add, built=True>,
#  <Activation name=conv5_block3_out, built=True>,
#  <GlobalAveragePooling2D name=avg_pool, built=True>]

# %%
resnet_model = Sequential()
resnet_model.add(model)
resnet_model.add(Flatten())
resnet_model.add(Dense(512, activation='relu'))
resnet_model.add(Dense(512, activation='relu'))
resnet_model.add(Dense(10, activation='softmax'))

# %%
resnet_model.build(input_shape=(None, 64, 64, 3))
resnet_model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',  # Use this for one-hot encoded labels
    metrics=['accuracy']
)

# %%
epochs=100
history = resnet_model.fit(
  train_dataset,
  validation_data=test_dataset,
  epochs=epochs,
  batch_size=32
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 30s 31ms/step - accuracy: 0.2569 - loss: 1.9968 - val_accuracy: 0.4560 - val_loss: 1.4503
# Epoch 2/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.4307 - loss: 1.5005 - val_accuracy: 0.4451 - val_loss: 1.4024
# Epoch 3/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.4617 - loss: 1.4311 - val_accuracy: 0.5394 - val_loss: 1.3187
# Epoch 4/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 18s 22ms/step - accuracy: 0.4855 - loss: 1.3765 - val_accuracy: 0.4986 - val_loss: 1.3907
# Epoch 5/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 13s 23ms/step - accuracy: 0.5000 - loss: 1.3445 - val_accuracy: 0.5581 - val_loss: 1.2381
# Epoch 6/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.5032 - loss: 1.3221 - val_accuracy: 0.5051 - val_loss: 1.3471
# Epoch 7/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.5231 - loss: 1.2867 - val_accuracy: 0.5611 - val_loss: 1.2009
# Epoch 8/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.5332 - loss: 1.2695 - val_accuracy: 0.5711 - val_loss: 1.2001
# Epoch 9/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.5409 - loss: 1.2383 - val_accuracy: 0.5632 - val_loss: 1.2091
# Epoch 10/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.5432 - loss: 1.2315 - val_accuracy: 0.5850 - val_loss: 1.1433
# Epoch 11/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.5592 - loss: 1.1914 - val_accuracy: 0.5898 - val_loss: 1.1236
# Epoch 12/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.5556 - loss: 1.1947 - val_accuracy: 0.5944 - val_loss: 1.1166
# Epoch 13/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - accuracy: 0.5598 - loss: 1.1904 - val_accuracy: 0.5958 - val_loss: 1.1303
# Epoch 14/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.5631 - loss: 1.1788 - val_accuracy: 0.4914 - val_loss: 1.2957
# Epoch 15/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.5673 - loss: 1.1675 - val_accuracy: 0.5961 - val_loss: 1.0826
# Epoch 16/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.5640 - loss: 1.1597 - val_accuracy: 0.5947 - val_loss: 1.0833
# Epoch 17/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.5651 - loss: 1.1666 - val_accuracy: 0.5931 - val_loss: 1.0842
# Epoch 18/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.5676 - loss: 1.1549 - val_accuracy: 0.6069 - val_loss: 1.0764
# Epoch 19/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.5835 - loss: 1.1178 - val_accuracy: 0.5688 - val_loss: 1.1559
# Epoch 20/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.5734 - loss: 1.1564 - val_accuracy: 0.6072 - val_loss: 1.0765
# Epoch 21/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.5847 - loss: 1.1164 - val_accuracy: 0.6065 - val_loss: 1.0764
# Epoch 22/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.5903 - loss: 1.1046 - val_accuracy: 0.5870 - val_loss: 1.1156
# Epoch 23/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 13s 23ms/step - accuracy: 0.5809 - loss: 1.1308 - val_accuracy: 0.6049 - val_loss: 1.0855
# Epoch 24/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.5840 - loss: 1.1024 - val_accuracy: 0.5088 - val_loss: 1.2779
# Epoch 25/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.5833 - loss: 1.1097 - val_accuracy: 0.6083 - val_loss: 1.0836
# Epoch 26/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.5844 - loss: 1.1021 - val_accuracy: 0.6069 - val_loss: 1.1121
# Epoch 27/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6029 - loss: 1.0793 - val_accuracy: 0.5845 - val_loss: 1.1205
# Epoch 28/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6004 - loss: 1.0827 - val_accuracy: 0.5583 - val_loss: 1.2022
# Epoch 29/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.5963 - loss: 1.0805 - val_accuracy: 0.6269 - val_loss: 1.0120
# Epoch 30/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.5930 - loss: 1.0840 - val_accuracy: 0.6100 - val_loss: 1.0601
# Epoch 31/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.5967 - loss: 1.0906 - val_accuracy: 0.6238 - val_loss: 1.0375
# Epoch 32/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6063 - loss: 1.0702 - val_accuracy: 0.6187 - val_loss: 1.0508
# Epoch 33/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.5956 - loss: 1.0873 - val_accuracy: 0.6176 - val_loss: 1.0360
# Epoch 34/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6107 - loss: 1.0605 - val_accuracy: 0.6197 - val_loss: 1.0438
# Epoch 35/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6154 - loss: 1.0417 - val_accuracy: 0.6384 - val_loss: 0.9926
# Epoch 36/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6155 - loss: 1.0432 - val_accuracy: 0.6368 - val_loss: 1.0049
# Epoch 37/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6051 - loss: 1.0680 - val_accuracy: 0.6350 - val_loss: 1.0350
# Epoch 38/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6104 - loss: 1.0602 - val_accuracy: 0.6275 - val_loss: 1.0278
# Epoch 39/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.6126 - loss: 1.0593 - val_accuracy: 0.6322 - val_loss: 1.0120
# Epoch 40/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6197 - loss: 1.0252 - val_accuracy: 0.6079 - val_loss: 1.0965
# Epoch 41/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - accuracy: 0.6124 - loss: 1.0385 - val_accuracy: 0.6479 - val_loss: 0.9819
# Epoch 42/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6214 - loss: 1.0188 - val_accuracy: 0.6051 - val_loss: 1.0663
# Epoch 43/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6139 - loss: 1.0360 - val_accuracy: 0.6250 - val_loss: 1.0321
# Epoch 44/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6305 - loss: 1.0064 - val_accuracy: 0.6215 - val_loss: 1.0405
# Epoch 45/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.6161 - loss: 1.0276 - val_accuracy: 0.6488 - val_loss: 0.9767
# Epoch 46/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.6128 - loss: 1.0247 - val_accuracy: 0.6289 - val_loss: 1.0177
# Epoch 47/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6134 - loss: 1.0279 - val_accuracy: 0.6266 - val_loss: 1.0446
# Epoch 48/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6169 - loss: 1.0232 - val_accuracy: 0.6380 - val_loss: 0.9866
# Epoch 49/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.6254 - loss: 1.0129 - val_accuracy: 0.6359 - val_loss: 0.9869
# Epoch 50/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6236 - loss: 1.0143 - val_accuracy: 0.6363 - val_loss: 0.9948
# Epoch 51/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.6239 - loss: 1.0202 - val_accuracy: 0.6294 - val_loss: 1.0295
# Epoch 52/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.6326 - loss: 0.9966 - val_accuracy: 0.6447 - val_loss: 0.9730
# Epoch 53/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6313 - loss: 0.9882 - val_accuracy: 0.6185 - val_loss: 1.0464
# Epoch 54/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6226 - loss: 1.0133 - val_accuracy: 0.6132 - val_loss: 1.0457
# Epoch 55/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6341 - loss: 0.9906 - val_accuracy: 0.6475 - val_loss: 0.9724
# Epoch 56/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.6329 - loss: 0.9918 - val_accuracy: 0.6493 - val_loss: 0.9746
# Epoch 57/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.6371 - loss: 0.9752 - val_accuracy: 0.6194 - val_loss: 1.0691
# Epoch 58/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6229 - loss: 1.0095 - val_accuracy: 0.6076 - val_loss: 1.0522
# Epoch 59/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.6362 - loss: 0.9804 - val_accuracy: 0.6595 - val_loss: 0.9836
# Epoch 60/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 22s 24ms/step - accuracy: 0.6435 - loss: 0.9677 - val_accuracy: 0.6484 - val_loss: 0.9856
# Epoch 61/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6406 - loss: 0.9658 - val_accuracy: 0.6544 - val_loss: 0.9672
# Epoch 62/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.6395 - loss: 0.9735 - val_accuracy: 0.6579 - val_loss: 0.9653
# Epoch 63/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6412 - loss: 0.9731 - val_accuracy: 0.6484 - val_loss: 0.9732
# Epoch 64/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6473 - loss: 0.9666 - val_accuracy: 0.6609 - val_loss: 0.9376
# Epoch 65/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6325 - loss: 0.9749 - val_accuracy: 0.5928 - val_loss: 1.0958
# Epoch 66/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6349 - loss: 0.9844 - val_accuracy: 0.5593 - val_loss: 1.2030
# Epoch 67/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.6377 - loss: 0.9777 - val_accuracy: 0.6458 - val_loss: 0.9821
# Epoch 68/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.6410 - loss: 0.9655 - val_accuracy: 0.6317 - val_loss: 1.0483
# Epoch 69/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6444 - loss: 0.9480 - val_accuracy: 0.5528 - val_loss: 1.2545
# Epoch 70/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6363 - loss: 0.9691 - val_accuracy: 0.6315 - val_loss: 0.9924
# Epoch 71/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.6501 - loss: 0.9417 - val_accuracy: 0.6083 - val_loss: 1.0658
# Epoch 72/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.6344 - loss: 0.9766 - val_accuracy: 0.6435 - val_loss: 0.9818
# Epoch 73/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6521 - loss: 0.9411 - val_accuracy: 0.6273 - val_loss: 1.0431
# Epoch 74/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.6476 - loss: 0.9487 - val_accuracy: 0.6176 - val_loss: 1.0656
# Epoch 75/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.6453 - loss: 0.9491 - val_accuracy: 0.6498 - val_loss: 0.9869
# Epoch 76/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6524 - loss: 0.9330 - val_accuracy: 0.6653 - val_loss: 0.9575
# Epoch 77/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6592 - loss: 0.9278 - val_accuracy: 0.6611 - val_loss: 0.9416
# Epoch 78/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 13s 23ms/step - accuracy: 0.6573 - loss: 0.9178 - val_accuracy: 0.6558 - val_loss: 0.9645
# Epoch 79/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.6514 - loss: 0.9368 - val_accuracy: 0.6588 - val_loss: 0.9616
# Epoch 80/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 13s 25ms/step - accuracy: 0.6432 - loss: 0.9617 - val_accuracy: 0.6377 - val_loss: 1.0031
# Epoch 81/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.6561 - loss: 0.9259 - val_accuracy: 0.6389 - val_loss: 0.9918
# Epoch 82/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6597 - loss: 0.9146 - val_accuracy: 0.6505 - val_loss: 0.9738
# Epoch 83/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 13s 23ms/step - accuracy: 0.6532 - loss: 0.9245 - val_accuracy: 0.6525 - val_loss: 0.9551
# Epoch 84/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6616 - loss: 0.9196 - val_accuracy: 0.6273 - val_loss: 1.0253
# Epoch 85/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6611 - loss: 0.9067 - val_accuracy: 0.6625 - val_loss: 0.9398
# Epoch 86/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6579 - loss: 0.9179 - val_accuracy: 0.6116 - val_loss: 1.0709
# Epoch 87/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.6616 - loss: 0.9123 - val_accuracy: 0.6387 - val_loss: 1.0175
# Epoch 88/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.6619 - loss: 0.9078 - val_accuracy: 0.6532 - val_loss: 0.9691
# Epoch 89/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6527 - loss: 0.9348 - val_accuracy: 0.6553 - val_loss: 0.9511
# Epoch 90/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 13s 23ms/step - accuracy: 0.6592 - loss: 0.9161 - val_accuracy: 0.6623 - val_loss: 0.9536
# Epoch 91/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 13s 23ms/step - accuracy: 0.6609 - loss: 0.8973 - val_accuracy: 0.6560 - val_loss: 0.9586
# Epoch 92/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.6485 - loss: 0.9350 - val_accuracy: 0.6667 - val_loss: 0.9393
# Epoch 93/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 13s 23ms/step - accuracy: 0.6579 - loss: 0.9177 - val_accuracy: 0.6581 - val_loss: 0.9552
# Epoch 94/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 13s 23ms/step - accuracy: 0.6697 - loss: 0.8867 - val_accuracy: 0.6620 - val_loss: 0.9460
# Epoch 95/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6704 - loss: 0.8840 - val_accuracy: 0.6653 - val_loss: 0.9640
# Epoch 96/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6677 - loss: 0.8911 - val_accuracy: 0.6345 - val_loss: 1.0362
# Epoch 97/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6728 - loss: 0.8835 - val_accuracy: 0.6657 - val_loss: 0.9472
# Epoch 98/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6634 - loss: 0.9085 - val_accuracy: 0.6375 - val_loss: 0.9906
# Epoch 99/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 13s 23ms/step - accuracy: 0.6620 - loss: 0.8925 - val_accuracy: 0.6514 - val_loss: 0.9759
# Epoch 100/100
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6706 - loss: 0.8851 - val_accuracy: 0.6412 - val_loss: 0.9803

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16.53, 11.69))
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set_xlabel('epoch')
ax1.set_ylabel('accuracy')
ax1.set_title('Accuracy over epoch')
ax1.legend(['Train', 'Test'], loc='upper left')

ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_xlabel('epoch')
ax2.set_ylabel('loss')
ax2.set_title('Loss over epoch')
ax2.legend(['Train', 'Test'], loc="upper right")

# %%
y_pred = []  # store predicted labels
y_true = []  # store true labels

# iterate over the dataset
for i, (image_batch, label_batch) in enumerate(test_dataset):   # use dataset.unbatch() with repeat
    # append true labels
    y_true.append(label_batch)
    # compute predictions
    preds = resnet_model.predict(image_batch)
    # append predicted labels
    y_pred.append(np.argmax(preds, axis =  1))
    if i==300:
        break

# convert the true and predicted labels into tensors
correct_labels = tf.concat([item for item in y_true], axis = 0)
correct_labels = np.argmax(correct_labels, axis=1)
predicted_labels = tf.concat([item for item in y_pred], axis = 0)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step

# %%
cm = confusion_matrix(correct_labels, predicted_labels)
cm
# Out:
# array([[868,   5,  36,  27,   3,   7,  44,   0,  59,  30],
#        [  2, 854, 100,   2,   0,  17,   0,   0,   5, 100],
#        [ 72,  19, 670,  46,  15,   8, 149,  48,  19,  12],
#        [ 95,   0,  78, 394,  30,  11, 162,  33,  93,   5],
#        [  6,   0,  13,  32, 693,   0,  83,  53,   8,   0],
#        [ 84,  47, 298,   6,   0, 157,  33,   0,  46,  51],
#        [118,   0, 147,  87,  15,  15, 476,   8,  20,   2],
#        [  0,   0,  92,  16,  21,   0,  47, 893,   4,   0],
#        [130,  17, 149, 187,   9,  74, 102,  11, 193,  24],
#        [ 26,  17,  16,   0,   0,  11,   0,   0,   7, 970]])

# %%
fig, ax = plt.subplots(figsize=(20, 20))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=train_dataset.class_indices)
disp.plot(ax=ax, cmap='Reds')
plt.show()

# %%
report = classification_report(correct_labels, predicted_labels, target_names=class_names)
print(report)
# Out:
#                       precision    recall  f1-score   support
#
#           AnnualCrop       0.62      0.80      0.70      1079
#               Forest       0.89      0.79      0.84      1080
# HerbaceousVegetation       0.42      0.63      0.50      1058
#              Highway       0.49      0.44      0.46       901
#           Industrial       0.88      0.78      0.83       888
#              Pasture       0.52      0.22      0.31       722
#        PermanentCrop       0.43      0.54      0.48       888
#          Residential       0.85      0.83      0.84      1073
#                River       0.43      0.22      0.29       896
#              SeaLake       0.81      0.93      0.87      1047
#
#             accuracy                           0.64      9632
#            macro avg       0.64      0.62      0.61      9632
#         weighted avg       0.65      0.64      0.63      9632

# %%
resnet_model.save('resnet50_model.h5')

# Get the size of the saved model file in bytes
model_size = os.path.getsize('resnet50_model.h5')

print(f"Model Size: {model_size} bytes")
print(f"Model Size: {model_size / (1024 * 1024)} MB")  # Convert to megabytes
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model Size: 110560624 bytes
# Model Size: 105.43882751464844 MB

# %%
start_time = time.time()
predictions = resnet_model.predict(test_dataset)
end_time = time.time()

inference_time = end_time - start_time

print(f"Inference Time: {inference_time} seconds")
# Out:
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step
# Inference Time: 5.772817611694336 seconds

# %%
resnet_model.summary()

# Get the total number of trainable parameters
total_params = resnet_model.count_params()
print(f"Total Trainable Parameters: {total_params}")
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)                │ (None, 2048)                │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       1,049,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │           5,130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 27,538,336 (105.05 MB)
#  Trainable params: 1,316,874 (5.02 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)
#  Optimizer params: 2,633,750 (10.05 MB)
# Total Trainable Parameters: 24904586

# %%
model.summary()
# Out:
# Model: "resnet50"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 64, 64, 3)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_pad (ZeroPadding2D) │ (None, 70, 70, 3)      │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_conv (Conv2D)       │ (None, 32, 32, 64)     │          9,472 │ conv1_pad[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_bn                  │ (None, 32, 32, 64)     │            256 │ conv1_conv[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_relu (Activation)   │ (None, 32, 32, 64)     │              0 │ conv1_bn[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool1_pad (ZeroPadding2D) │ (None, 34, 34, 64)     │              0 │ conv1_relu[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool1_pool (MaxPooling2D) │ (None, 16, 16, 64)     │              0 │ pool1_pad[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_conv       │ (None, 16, 16, 64)     │          4,160 │ pool1_pool[0][0]       │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_bn         │ (None, 16, 16, 64)     │            256 │ conv2_block1_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_relu       │ (None, 16, 16, 64)     │              0 │ conv2_block1_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_2_conv       │ (None, 16, 16, 64)     │         36,928 │ conv2_block1_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_2_bn         │ (None, 16, 16, 64)     │            256 │ conv2_block1_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_2_relu       │ (None, 16, 16, 64)     │              0 │ conv2_block1_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_0_conv       │ (None, 16, 16, 256)    │         16,640 │ pool1_pool[0][0]       │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_3_conv       │ (None, 16, 16, 256)    │         16,640 │ conv2_block1_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_0_bn         │ (None, 16, 16, 256)    │          1,024 │ conv2_block1_0_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_3_bn         │ (None, 16, 16, 256)    │          1,024 │ conv2_block1_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_add (Add)    │ (None, 16, 16, 256)    │              0 │ conv2_block1_0_bn[0][… │
# │                           │                        │                │ conv2_block1_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_out          │ (None, 16, 16, 256)    │              0 │ conv2_block1_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_1_conv       │ (None, 16, 16, 64)     │         16,448 │ conv2_block1_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_1_bn         │ (None, 16, 16, 64)     │            256 │ conv2_block2_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_1_relu       │ (None, 16, 16, 64)     │              0 │ conv2_block2_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_2_conv       │ (None, 16, 16, 64)     │         36,928 │ conv2_block2_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_2_bn         │ (None, 16, 16, 64)     │            256 │ conv2_block2_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_2_relu       │ (None, 16, 16, 64)     │              0 │ conv2_block2_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_3_conv       │ (None, 16, 16, 256)    │         16,640 │ conv2_block2_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_3_bn         │ (None, 16, 16, 256)    │          1,024 │ conv2_block2_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_add (Add)    │ (None, 16, 16, 256)    │              0 │ conv2_block1_out[0][0… │
# │                           │                        │                │ conv2_block2_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_out          │ (None, 16, 16, 256)    │              0 │ conv2_block2_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_1_conv       │ (None, 16, 16, 64)     │         16,448 │ conv2_block2_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_1_bn         │ (None, 16, 16, 64)     │            256 │ conv2_block3_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_1_relu       │ (None, 16, 16, 64)     │              0 │ conv2_block3_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_2_conv       │ (None, 16, 16, 64)     │         36,928 │ conv2_block3_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_2_bn         │ (None, 16, 16, 64)     │            256 │ conv2_block3_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_2_relu       │ (None, 16, 16, 64)     │              0 │ conv2_block3_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_3_conv       │ (None, 16, 16, 256)    │         16,640 │ conv2_block3_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_3_bn         │ (None, 16, 16, 256)    │          1,024 │ conv2_block3_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_add (Add)    │ (None, 16, 16, 256)    │              0 │ conv2_block2_out[0][0… │
# │                           │                        │                │ conv2_block3_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_out          │ (None, 16, 16, 256)    │              0 │ conv2_block3_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_1_conv       │ (None, 8, 8, 128)      │         32,896 │ conv2_block3_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_1_bn         │ (None, 8, 8, 128)      │            512 │ conv3_block1_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_1_relu       │ (None, 8, 8, 128)      │              0 │ conv3_block1_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_2_conv       │ (None, 8, 8, 128)      │        147,584 │ conv3_block1_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_2_bn         │ (None, 8, 8, 128)      │            512 │ conv3_block1_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_2_relu       │ (None, 8, 8, 128)      │              0 │ conv3_block1_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_0_conv       │ (None, 8, 8, 512)      │        131,584 │ conv2_block3_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_3_conv       │ (None, 8, 8, 512)      │         66,048 │ conv3_block1_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_0_bn         │ (None, 8, 8, 512)      │          2,048 │ conv3_block1_0_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_3_bn         │ (None, 8, 8, 512)      │          2,048 │ conv3_block1_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_add (Add)    │ (None, 8, 8, 512)      │              0 │ conv3_block1_0_bn[0][… │
# │                           │                        │                │ conv3_block1_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_out          │ (None, 8, 8, 512)      │              0 │ conv3_block1_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_1_conv       │ (None, 8, 8, 128)      │         65,664 │ conv3_block1_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_1_bn         │ (None, 8, 8, 128)      │            512 │ conv3_block2_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_1_relu       │ (None, 8, 8, 128)      │              0 │ conv3_block2_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_2_conv       │ (None, 8, 8, 128)      │        147,584 │ conv3_block2_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_2_bn         │ (None, 8, 8, 128)      │            512 │ conv3_block2_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_2_relu       │ (None, 8, 8, 128)      │              0 │ conv3_block2_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_3_conv       │ (None, 8, 8, 512)      │         66,048 │ conv3_block2_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_3_bn         │ (None, 8, 8, 512)      │          2,048 │ conv3_block2_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_add (Add)    │ (None, 8, 8, 512)      │              0 │ conv3_block1_out[0][0… │
# │                           │                        │                │ conv3_block2_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_out          │ (None, 8, 8, 512)      │              0 │ conv3_block2_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_1_conv       │ (None, 8, 8, 128)      │         65,664 │ conv3_block2_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_1_bn         │ (None, 8, 8, 128)      │            512 │ conv3_block3_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_1_relu       │ (None, 8, 8, 128)      │              0 │ conv3_block3_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_2_conv       │ (None, 8, 8, 128)      │        147,584 │ conv3_block3_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_2_bn         │ (None, 8, 8, 128)      │            512 │ conv3_block3_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_2_relu       │ (None, 8, 8, 128)      │              0 │ conv3_block3_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_3_conv       │ (None, 8, 8, 512)      │         66,048 │ conv3_block3_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_3_bn         │ (None, 8, 8, 512)      │          2,048 │ conv3_block3_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_add (Add)    │ (None, 8, 8, 512)      │              0 │ conv3_block2_out[0][0… │
# │                           │                        │                │ conv3_block3_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_out          │ (None, 8, 8, 512)      │              0 │ conv3_block3_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_1_conv       │ (None, 8, 8, 128)      │         65,664 │ conv3_block3_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_1_bn         │ (None, 8, 8, 128)      │            512 │ conv3_block4_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_1_relu       │ (None, 8, 8, 128)      │              0 │ conv3_block4_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_2_conv       │ (None, 8, 8, 128)      │        147,584 │ conv3_block4_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_2_bn         │ (None, 8, 8, 128)      │            512 │ conv3_block4_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_2_relu       │ (None, 8, 8, 128)      │              0 │ conv3_block4_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_3_conv       │ (None, 8, 8, 512)      │         66,048 │ conv3_block4_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_3_bn         │ (None, 8, 8, 512)      │          2,048 │ conv3_block4_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_add (Add)    │ (None, 8, 8, 512)      │              0 │ conv3_block3_out[0][0… │
# │                           │                        │                │ conv3_block4_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_out          │ (None, 8, 8, 512)      │              0 │ conv3_block4_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_1_conv       │ (None, 4, 4, 256)      │        131,328 │ conv3_block4_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_1_bn         │ (None, 4, 4, 256)      │          1,024 │ conv4_block1_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_1_relu       │ (None, 4, 4, 256)      │              0 │ conv4_block1_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_2_conv       │ (None, 4, 4, 256)      │        590,080 │ conv4_block1_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_2_bn         │ (None, 4, 4, 256)      │          1,024 │ conv4_block1_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_2_relu       │ (None, 4, 4, 256)      │              0 │ conv4_block1_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_0_conv       │ (None, 4, 4, 1024)     │        525,312 │ conv3_block4_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_3_conv       │ (None, 4, 4, 1024)     │        263,168 │ conv4_block1_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_0_bn         │ (None, 4, 4, 1024)     │          4,096 │ conv4_block1_0_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_3_bn         │ (None, 4, 4, 1024)     │          4,096 │ conv4_block1_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_add (Add)    │ (None, 4, 4, 1024)     │              0 │ conv4_block1_0_bn[0][… │
# │                           │                        │                │ conv4_block1_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_out          │ (None, 4, 4, 1024)     │              0 │ conv4_block1_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_1_conv       │ (None, 4, 4, 256)      │        262,400 │ conv4_block1_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_1_bn         │ (None, 4, 4, 256)      │          1,024 │ conv4_block2_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_1_relu       │ (None, 4, 4, 256)      │              0 │ conv4_block2_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_2_conv       │ (None, 4, 4, 256)      │        590,080 │ conv4_block2_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_2_bn         │ (None, 4, 4, 256)      │          1,024 │ conv4_block2_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_2_relu       │ (None, 4, 4, 256)      │              0 │ conv4_block2_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_3_conv       │ (None, 4, 4, 1024)     │        263,168 │ conv4_block2_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_3_bn         │ (None, 4, 4, 1024)     │          4,096 │ conv4_block2_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_add (Add)    │ (None, 4, 4, 1024)     │              0 │ conv4_block1_out[0][0… │
# │                           │                        │                │ conv4_block2_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_out          │ (None, 4, 4, 1024)     │              0 │ conv4_block2_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_1_conv       │ (None, 4, 4, 256)      │        262,400 │ conv4_block2_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_1_bn         │ (None, 4, 4, 256)      │          1,024 │ conv4_block3_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_1_relu       │ (None, 4, 4, 256)      │              0 │ conv4_block3_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_2_conv       │ (None, 4, 4, 256)      │        590,080 │ conv4_block3_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_2_bn         │ (None, 4, 4, 256)      │          1,024 │ conv4_block3_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_2_relu       │ (None, 4, 4, 256)      │              0 │ conv4_block3_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_3_conv       │ (None, 4, 4, 1024)     │        263,168 │ conv4_block3_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_3_bn         │ (None, 4, 4, 1024)     │          4,096 │ conv4_block3_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_add (Add)    │ (None, 4, 4, 1024)     │              0 │ conv4_block2_out[0][0… │
# │                           │                        │                │ conv4_block3_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_out          │ (None, 4, 4, 1024)     │              0 │ conv4_block3_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_1_conv       │ (None, 4, 4, 256)      │        262,400 │ conv4_block3_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_1_bn         │ (None, 4, 4, 256)      │          1,024 │ conv4_block4_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_1_relu       │ (None, 4, 4, 256)      │              0 │ conv4_block4_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_2_conv       │ (None, 4, 4, 256)      │        590,080 │ conv4_block4_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_2_bn         │ (None, 4, 4, 256)      │          1,024 │ conv4_block4_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_2_relu       │ (None, 4, 4, 256)      │              0 │ conv4_block4_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_3_conv       │ (None, 4, 4, 1024)     │        263,168 │ conv4_block4_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_3_bn         │ (None, 4, 4, 1024)     │          4,096 │ conv4_block4_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_add (Add)    │ (None, 4, 4, 1024)     │              0 │ conv4_block3_out[0][0… │
# │                           │                        │                │ conv4_block4_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_out          │ (None, 4, 4, 1024)     │              0 │ conv4_block4_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_1_conv       │ (None, 4, 4, 256)      │        262,400 │ conv4_block4_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_1_bn         │ (None, 4, 4, 256)      │          1,024 │ conv4_block5_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_1_relu       │ (None, 4, 4, 256)      │              0 │ conv4_block5_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_2_conv       │ (None, 4, 4, 256)      │        590,080 │ conv4_block5_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_2_bn         │ (None, 4, 4, 256)      │          1,024 │ conv4_block5_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_2_relu       │ (None, 4, 4, 256)      │              0 │ conv4_block5_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_3_conv       │ (None, 4, 4, 1024)     │        263,168 │ conv4_block5_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_3_bn         │ (None, 4, 4, 1024)     │          4,096 │ conv4_block5_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_add (Add)    │ (None, 4, 4, 1024)     │              0 │ conv4_block4_out[0][0… │
# │                           │                        │                │ conv4_block5_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_out          │ (None, 4, 4, 1024)     │              0 │ conv4_block5_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_1_conv       │ (None, 4, 4, 256)      │        262,400 │ conv4_block5_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_1_bn         │ (None, 4, 4, 256)      │          1,024 │ conv4_block6_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_1_relu       │ (None, 4, 4, 256)      │              0 │ conv4_block6_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_2_conv       │ (None, 4, 4, 256)      │        590,080 │ conv4_block6_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_2_bn         │ (None, 4, 4, 256)      │          1,024 │ conv4_block6_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_2_relu       │ (None, 4, 4, 256)      │              0 │ conv4_block6_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_3_conv       │ (None, 4, 4, 1024)     │        263,168 │ conv4_block6_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_3_bn         │ (None, 4, 4, 1024)     │          4,096 │ conv4_block6_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_add (Add)    │ (None, 4, 4, 1024)     │              0 │ conv4_block5_out[0][0… │
# │                           │                        │                │ conv4_block6_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_out          │ (None, 4, 4, 1024)     │              0 │ conv4_block6_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_1_conv       │ (None, 2, 2, 512)      │        524,800 │ conv4_block6_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_1_bn         │ (None, 2, 2, 512)      │          2,048 │ conv5_block1_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_1_relu       │ (None, 2, 2, 512)      │              0 │ conv5_block1_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_2_conv       │ (None, 2, 2, 512)      │      2,359,808 │ conv5_block1_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_2_bn         │ (None, 2, 2, 512)      │          2,048 │ conv5_block1_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_2_relu       │ (None, 2, 2, 512)      │              0 │ conv5_block1_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_0_conv       │ (None, 2, 2, 2048)     │      2,099,200 │ conv4_block6_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_3_conv       │ (None, 2, 2, 2048)     │      1,050,624 │ conv5_block1_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_0_bn         │ (None, 2, 2, 2048)     │          8,192 │ conv5_block1_0_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_3_bn         │ (None, 2, 2, 2048)     │          8,192 │ conv5_block1_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_add (Add)    │ (None, 2, 2, 2048)     │              0 │ conv5_block1_0_bn[0][… │
# │                           │                        │                │ conv5_block1_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_out          │ (None, 2, 2, 2048)     │              0 │ conv5_block1_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_1_conv       │ (None, 2, 2, 512)      │      1,049,088 │ conv5_block1_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_1_bn         │ (None, 2, 2, 512)      │          2,048 │ conv5_block2_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_1_relu       │ (None, 2, 2, 512)      │              0 │ conv5_block2_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_2_conv       │ (None, 2, 2, 512)      │      2,359,808 │ conv5_block2_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_2_bn         │ (None, 2, 2, 512)      │          2,048 │ conv5_block2_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_2_relu       │ (None, 2, 2, 512)      │              0 │ conv5_block2_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_3_conv       │ (None, 2, 2, 2048)     │      1,050,624 │ conv5_block2_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_3_bn         │ (None, 2, 2, 2048)     │          8,192 │ conv5_block2_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_add (Add)    │ (None, 2, 2, 2048)     │              0 │ conv5_block1_out[0][0… │
# │                           │                        │                │ conv5_block2_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_out          │ (None, 2, 2, 2048)     │              0 │ conv5_block2_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_1_conv       │ (None, 2, 2, 512)      │      1,049,088 │ conv5_block2_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_1_bn         │ (None, 2, 2, 512)      │          2,048 │ conv5_block3_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_1_relu       │ (None, 2, 2, 512)      │              0 │ conv5_block3_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_2_conv       │ (None, 2, 2, 512)      │      2,359,808 │ conv5_block3_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_2_bn         │ (None, 2, 2, 512)      │          2,048 │ conv5_block3_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_2_relu       │ (None, 2, 2, 512)      │              0 │ conv5_block3_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_3_conv       │ (None, 2, 2, 2048)     │      1,050,624 │ conv5_block3_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_3_bn         │ (None, 2, 2, 2048)     │          8,192 │ conv5_block3_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_add (Add)    │ (None, 2, 2, 2048)     │              0 │ conv5_block2_out[0][0… │
# │                           │                        │                │ conv5_block3_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_out          │ (None, 2, 2, 2048)     │              0 │ conv5_block3_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ avg_pool                  │ (None, 2048)           │              0 │ conv5_block3_out[0][0] │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 23,587,712 (89.98 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
training_accuracy = history.history['accuracy'][-1]  # Accuracy of the last epoch
validation_accuracy = history.history['val_accuracy'][-1]  # Validation accuracy of the last epoch

print(f"Training Accuracy: {training_accuracy}")
print(f"Validation Accuracy: {validation_accuracy}")
# Out:
# Training Accuracy: 0.6714120507240295
# Validation Accuracy: 0.6412037014961243

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Get predictions for the validation set
y_pred = resnet_model.predict(test_dataset)
y_pred = np.argmax(y_pred, axis=1)  # Convert predictions to class labels

# Get true labels for the validation set
y_true = test_dataset.classes  # Assuming test_dataset has a 'classes' attribute

# Calculate metrics
precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')

print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step
# Precision: 0.09942677913761902
# Recall: 0.10208333333333333
# F1 Score: 0.09798396008898157
